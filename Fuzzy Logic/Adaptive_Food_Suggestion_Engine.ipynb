# %%
pip install -U scikit-fuzzy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 994.0/994.0 KB 16.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scikit-fuzzy: filename=scikit_fuzzy-0.4.2-py3-none-any.whl size=894088 sha256=5d7e7d6810d9a23fd04f9b5a6f4e72ab3ef20aaf356ebf0a52eb00128d877515
#   Stored in directory: /root/.cache/pip/wheels/2c/04/80/7eefb1a2de7d36aefd06432fab2a1486caf0a0596a7067391a
# Successfully built scikit-fuzzy
# ...

# %%
import numpy as np
import skfuzzy as fuzz
from skfuzzy import control as ctrl
#input
taste = ctrl.Antecedent(np.arange(0,3, 0.5), 'taste')
environment = ctrl.Antecedent(np.arange(0, 3, 0.5), 'environment')
budget = ctrl.Antecedent(np.arange(0,3, 0.5), 'budget')
review = ctrl.Antecedent(np.arange(0,3, 0.5), 'review')
location = ctrl.Antecedent(np.arange(0,3, 0.5), 'location')
#output
level = ctrl.Consequent(np.arange(0, 15, 1), 'level')
#------------------#
taste['L'] = fuzz.trimf(taste.universe,[0, 0.5, 1])
taste['M'] = fuzz.trimf(taste.universe, [1, 1.5, 2])
taste['H'] = fuzz.trimf(taste.universe, [2, 2.5, 3])
#------------------#
environment['L'] = fuzz.trimf(environment.universe,[0, 0.5, 1])
environment['M'] = fuzz.trimf(environment.universe, [1, 1.5, 2])
environment['H'] = fuzz.trimf(environment.universe, [2, 2.5, 3])
#------------------#
review['L'] = fuzz.trimf(review.universe,[0, 0.5, 1])
review['M'] = fuzz.trimf(review.universe, [1, 1.5, 2])
review['H'] = fuzz.trimf(review.universe, [2, 2.5, 3])
#------------------#
location['L'] = fuzz.trimf(location.universe,[0, 0.5, 1])
location['M'] = fuzz.trimf(location.universe, [1, 1.5, 2])
location['H'] = fuzz.trimf(location.universe, [2, 2.5, 3])
#------------------#
budget['L'] = fuzz.trimf(budget.universe,[0, 0.5, 1])
budget['M'] = fuzz.trimf(budget.universe, [1, 1.5, 2])
budget['H'] = fuzz.trimf(budget.universe, [2, 2.5, 3])
#------------------#
level['L1'] = fuzz.trimf(level.universe,[0, 1.5, 3])
level['L2'] = fuzz.trimf(level.universe, [3, 4.5, 6])
level['L3'] = fuzz.trimf(level.universe, [6, 7.5, 9])
level['L4'] = fuzz.trimf(level.universe, [9, 10.5, 12])
level['L5'] = fuzz.trimf(level.universe, [12, 13.5, 15])

rule_1 = ctrl.Rule(taste['L'] & environment['L'] & review['L'] & location['L'] & budget['L'], level['L1'])
rule_2 = ctrl.Rule(taste['L'] & environment['L'] & review['L'] & location['L'] & budget['M'], level['L1'])
rule_3 = ctrl.Rule(taste['L'] & environment['L'] & review['L'] & location['L'] & budget['H'], level['L1'])
rule_4 = ctrl.Rule(taste['L'] & environment['L'] & review['L'] & location['M'] & budget['L'], level['L1'])
rule_5 = ctrl.Rule(taste['L'] & environment['L'] & review['L'] & location['M'] & budget['M'], level['L1'])
rule_6 = ctrl.Rule(taste['L'] & environment['L'] & review['L'] & location['M'] & budget['H'], level['L1'])
rule_7 = ctrl.Rule(taste['L'] & environment['L'] & review['L'] & location['H'] & budget['L'], level['L1'])
rule_8 = ctrl.Rule(taste['L'] & environment['L'] & review['L'] & location['H'] & budget['M'], level['L1'])
rule_9 = ctrl.Rule(taste['L'] & environment['L'] & review['L'] & location['H'] & budget['H'], level['L1'])
rule_10 = ctrl.Rule(taste['L'] & environment['L'] & review['M'] & location['L'] & budget['L'], level['L2'])
rule_11 = ctrl.Rule(taste['L'] & environment['L'] & review['M'] & location['L'] & budget['M'], level['L2'])
rule_12 = ctrl.Rule(taste['L'] & environment['L'] & review['M'] & location['L'] & budget['H'], level['L2'])
rule_13 = ctrl.Rule(taste['L'] & environment['L'] & review['M'] & location['M'] & budget['L'], level['L2'])
rule_14 = ctrl.Rule(taste['L'] & environment['L'] & review['M'] & location['M'] & budget['M'], level['L2'])
rule_15 = ctrl.Rule(taste['L'] & environment['L'] & review['M'] & location['M'] & budget['H'], level['L2'])
rule_16 = ctrl.Rule(taste['L'] & environment['L'] & review['M'] & location['H'] & budget['L'], level['L1'])
rule_17 = ctrl.Rule(taste['L'] & environment['L'] & review['M'] & location['H'] & budget['M'], level['L1'])
rule_18 = ctrl.Rule(taste['L'] & environment['L'] & review['M'] & location['H'] & budget['H'], level['L1'])
rule_19 = ctrl.Rule(taste['L'] & environment['L'] & review['H'] & location['L'] & budget['L'], level['L2'])
rule_20 = ctrl.Rule(taste['L'] & environment['L'] & review['H'] & location['L'] & budget['M'], level['L2'])
rule_21 = ctrl.Rule(taste['L'] & environment['L'] & review['H'] & location['L'] & budget['H'], level['L2'])
rule_22 = ctrl.Rule(taste['L'] & environment['L'] & review['H'] & location['M'] & budget['L'], level['L2'])
rule_23 = ctrl.Rule(taste['L'] & environment['L'] & review['H'] & location['M'] & budget['M'], level['L2'])
rule_24 = ctrl.Rule(taste['L'] & environment['L'] & review['H'] & location['M'] & budget['H'], level['L2'])
rule_25 = ctrl.Rule(taste['L'] & environment['L'] & review['H'] & location['H'] & budget['L'], level['L2'])
rule_26 = ctrl.Rule(taste['L'] & environment['L'] & review['H'] & location['H'] & budget['M'], level['L2'])
rule_27 = ctrl.Rule(taste['L'] & environment['L'] & review['H'] & location['H'] & budget['H'], level['L2'])
rule_28 = ctrl.Rule(taste['L'] & environment['M'] & review['L'] & location['L'] & budget['L'], level['L2'])
rule_29 = ctrl.Rule(taste['L'] & environment['M'] & review['L'] & location['L'] & budget['M'], level['L2'])
rule_30 = ctrl.Rule(taste['L'] & environment['M'] & review['L'] & location['L'] & budget['H'], level['L2'])
rule_31 = ctrl.Rule(taste['L'] & environment['M'] & review['L'] & location['M'] & budget['L'], level['L2'])
rule_32 = ctrl.Rule(taste['L'] & environment['M'] & review['L'] & location['M'] & budget['M'], level['L3'])
rule_33 = ctrl.Rule(taste['L'] & environment['M'] & review['L'] & location['M'] & budget['H'], level['L3'])
rule_34 = ctrl.Rule(taste['L'] & environment['M'] & review['L'] & location['H'] & budget['L'], level['L3'])
rule_35 = ctrl.Rule(taste['L'] & environment['M'] & review['L'] & location['H'] & budget['M'], level['L3'])
rule_36 = ctrl.Rule(taste['L'] & environment['M'] & review['L'] & location['H'] & budget['H'], level['L3'])
rule_37 = ctrl.Rule(taste['L'] & environment['M'] & review['M'] & location['L'] & budget['L'], level['L3'])
rule_38 = ctrl.Rule(taste['L'] & environment['M'] & review['M'] & location['L'] & budget['M'], level['L3'])
rule_39 = ctrl.Rule(taste['L'] & environment['M'] & review['M'] & location['L'] & budget['H'], level['L3'])
rule_40 = ctrl.Rule(taste['L'] & environment['M'] & review['M'] & location['M'] & budget['L'], level['L3'])
rule_41 = ctrl.Rule(taste['L'] & environment['M'] & review['M'] & location['M'] & budget['M'], level['L3'])
rule_42 = ctrl.Rule(taste['L'] & environment['M'] & review['M'] & location['M'] & budget['H'], level['L3'])
rule_43 = ctrl.Rule(taste['L'] & environment['M'] & review['M'] & location['H'] & budget['L'], level['L3'])
rule_44 = ctrl.Rule(taste['L'] & environment['M'] & review['M'] & location['H'] & budget['M'], level['L3'])
rule_45 = ctrl.Rule(taste['L'] & environment['M'] & review['M'] & location['H'] & budget['H'], level['L3'])
rule_46 = ctrl.Rule(taste['L'] & environment['M'] & review['H'] & location['L'] & budget['L'], level['L3'])
rule_47 = ctrl.Rule(taste['L'] & environment['M'] & review['H'] & location['L'] & budget['M'], level['L3'])
rule_48 = ctrl.Rule(taste['L'] & environment['M'] & review['H'] & location['L'] & budget['H'], level['L3'])
rule_49 = ctrl.Rule(taste['L'] & environment['M'] & review['H'] & location['M'] & budget['L'], level['L3'])
rule_50 = ctrl.Rule(taste['L'] & environment['M'] & review['H'] & location['M'] & budget['M'], level['L3'])
rule_51 = ctrl.Rule(taste['L'] & environment['M'] & review['H'] & location['M'] & budget['H'], level['L3'])
rule_52 = ctrl.Rule(taste['L'] & environment['M'] & review['H'] & location['H'] & budget['L'], level['L3'])
rule_53 = ctrl.Rule(taste['L'] & environment['M'] & review['H'] & location['H'] & budget['M'], level['L3'])
rule_54 = ctrl.Rule(taste['L'] & environment['M'] & review['H'] & location['H'] & budget['H'], level['L3'])
rule_55 = ctrl.Rule(taste['L'] & environment['H'] & review['L'] & location['L'] & budget['L'], level['L3'])
rule_56 = ctrl.Rule(taste['L'] & environment['H'] & review['L'] & location['L'] & budget['M'], level['L3'])
rule_57 = ctrl.Rule(taste['L'] & environment['H'] & review['L'] & location['L'] & budget['H'], level['L3'])
rule_58 = ctrl.Rule(taste['L'] & environment['H'] & review['L'] & location['M'] & budget['L'], level['L4'])
rule_59 = ctrl.Rule(taste['L'] & environment['H'] & review['L'] & location['M'] & budget['M'], level['L4'])
rule_60 = ctrl.Rule(taste['L'] & environment['H'] & review['L'] & location['M'] & budget['H'], level['L4'])
rule_61 = ctrl.Rule(taste['L'] & environment['H'] & review['L'] & location['H'] & budget['L'], level['L4'])
rule_62 = ctrl.Rule(taste['L'] & environment['H'] & review['L'] & location['H'] & budget['M'], level['L4'])
rule_63 = ctrl.Rule(taste['L'] & environment['H'] & review['L'] & location['H'] & budget['H'], level['L4'])
rule_64 = ctrl.Rule(taste['L'] & environment['H'] & review['M'] & location['L'] & budget['L'], level['L4'])
rule_65 = ctrl.Rule(taste['L'] & environment['H'] & review['M'] & location['L'] & budget['M'], level['L4'])
rule_66 = ctrl.Rule(taste['L'] & environment['H'] & review['M'] & location['L'] & budget['H'], level['L4'])
rule_67 = ctrl.Rule(taste['L'] & environment['H'] & review['M'] & location['M'] & budget['L'], level['L4'])
rule_68 = ctrl.Rule(taste['L'] & environment['H'] & review['M'] & location['M'] & budget['M'], level['L4'])
rule_69 = ctrl.Rule(taste['L'] & environment['H'] & review['M'] & location['M'] & budget['H'], level['L4'])
rule_70 = ctrl.Rule(taste['L'] & environment['H'] & review['M'] & location['H'] & budget['L'], level['L4'])
rule_71 = ctrl.Rule(taste['L'] & environment['H'] & review['M'] & location['H'] & budget['M'], level['L4'])
rule_72 = ctrl.Rule(taste['L'] & environment['H'] & review['M'] & location['H'] & budget['H'], level['L4'])
rule_73 = ctrl.Rule(taste['L'] & environment['H'] & review['H'] & location['L'] & budget['L'], level['L4'])
rule_74 = ctrl.Rule(taste['L'] & environment['H'] & review['H'] & location['L'] & budget['M'], level['L4'])
rule_75 = ctrl.Rule(taste['L'] & environment['H'] & review['H'] & location['L'] & budget['H'], level['L4'])
rule_76 = ctrl.Rule(taste['L'] & environment['H'] & review['H'] & location['M'] & budget['L'], level['L4'])
rule_77 = ctrl.Rule(taste['L'] & environment['H'] & review['H'] & location['M'] & budget['M'], level['L4'])
rule_77 = ctrl.Rule(taste['L'] & environment['H'] & review['H'] & location['M'] & budget['H'], level['L4'])
rule_78 = ctrl.Rule(taste['L'] & environment['H'] & review['H'] & location['H'] & budget['L'], level['L4'])
rule_79 = ctrl.Rule(taste['L'] & environment['H'] & review['H'] & location['H'] & budget['M'], level['L4'])
rule_80 = ctrl.Rule(taste['L'] & environment['H'] & review['H'] & location['H'] & budget['H'], level['L4'])
rule_81 = ctrl.Rule(taste['M'] & environment['L'] & review['L'] & location['L'] & budget['L'], level['L4'])
rule_82 = ctrl.Rule(taste['M'] & environment['L'] & review['L'] & location['L'] & budget['M'], level['L3'])
rule_83 = ctrl.Rule(taste['M'] & environment['L'] & review['L'] & location['L'] & budget['H'], level['L3'])
rule_84 = ctrl.Rule(taste['M'] & environment['L'] & review['L'] & location['M'] & budget['L'], level['L3'])
rule_85 = ctrl.Rule(taste['M'] & environment['L'] & review['L'] & location['M'] & budget['M'], level['L3'])
rule_86 = ctrl.Rule(taste['M'] & environment['L'] & review['L'] & location['M'] & budget['H'], level['L3'])
rule_87 = ctrl.Rule(taste['M'] & environment['L'] & review['L'] & location['H'] & budget['L'], level['L3'])
rule_88 = ctrl.Rule(taste['M'] & environment['L'] & review['L'] & location['H'] & budget['M'], level['L3'])
rule_89 = ctrl.Rule(taste['M'] & environment['L'] & review['L'] & location['H'] & budget['H'], level['L5'])
rule_90 = ctrl.Rule(taste['M'] & environment['L'] & review['M'] & location['L'] & budget['L'], level['L5'])
rule_91 = ctrl.Rule(taste['M'] & environment['L'] & review['M'] & location['L'] & budget['M'], level['L5'])
rule_92 = ctrl.Rule(taste['M'] & environment['L'] & review['M'] & location['L'] & budget['H'], level['L5'])
rule_93 = ctrl.Rule(taste['M'] & environment['L'] & review['M'] & location['M'] & budget['L'], level['L5'])
rule_94 = ctrl.Rule(taste['M'] & environment['L'] & review['M'] & location['M'] & budget['M'], level['L5'])
rule_95 = ctrl.Rule(taste['M'] & environment['L'] & review['M'] & location['M'] & budget['H'], level['L5'])
rule_96 = ctrl.Rule(taste['M'] & environment['L'] & review['M'] & location['H'] & budget['L'], level['L5'])
rule_97 = ctrl.Rule(taste['M'] & environment['L'] & review['M'] & location['H'] & budget['M'], level['L5'])
rule_98 = ctrl.Rule(taste['M'] & environment['L'] & review['M'] & location['H'] & budget['H'], level['L5'])
rule_99 = ctrl.Rule(taste['M'] & environment['L'] & review['H'] & location['L'] & budget['L'], level['L5'])
rule_100 = ctrl.Rule(taste['M'] & environment['L'] & review['H'] & location['L'] & budget['M'], level['L5'])
rule_101 = ctrl.Rule(taste['M'] & environment['L'] & review['H'] & location['L'] & budget['H'], level['L5'])
rule_102 = ctrl.Rule(taste['M'] & environment['L'] & review['H'] & location['M'] & budget['L'], level['L5'])
rule_103 = ctrl.Rule(taste['M'] & environment['L'] & review['H'] & location['M'] & budget['M'], level['L5'])
rule_104 = ctrl.Rule(taste['M'] & environment['L'] & review['H'] & location['M'] & budget['H'], level['L5'])
rule_105 = ctrl.Rule(taste['M'] & environment['L'] & review['H'] & location['H'] & budget['L'], level['L5'])
rule_106 = ctrl.Rule(taste['M'] & environment['L'] & review['H'] & location['H'] & budget['M'], level['L5'])
rule_107 = ctrl.Rule(taste['M'] & environment['L'] & review['H'] & location['H'] & budget['H'], level['L5'])
rule_108 = ctrl.Rule(taste['M'] & environment['M'] & review['L'] & location['L'] & budget['L'], level['L5'])
rule_109 = ctrl.Rule(taste['M'] & environment['M'] & review['L'] & location['L'] & budget['M'], level['L5'])
rule_110 = ctrl.Rule(taste['M'] & environment['M'] & review['L'] & location['L'] & budget['H'], level['L5'])
rule_111 = ctrl.Rule(taste['M'] & environment['M'] & review['L'] & location['M'] & budget['L'], level['L5'])
rule_112 = ctrl.Rule(taste['M'] & environment['M'] & review['L'] & location['M'] & budget['M'], level['L5'])
rule_113 = ctrl.Rule(taste['M'] & environment['M'] & review['L'] & location['M'] & budget['H'], level['L5'])
rule_114 = ctrl.Rule(taste['M'] & environment['M'] & review['L'] & location['H'] & budget['L'], level['L5'])
rule_115 = ctrl.Rule(taste['M'] & environment['M'] & review['L'] & location['H'] & budget['M'], level['L2'])
rule_116 = ctrl.Rule(taste['M'] & environment['M'] & review['L'] & location['H'] & budget['H'], level['L2'])
rule_117 = ctrl.Rule(taste['M'] & environment['M'] & review['M'] & location['L'] & budget['L'], level['L2'])
rule_118 = ctrl.Rule(taste['M'] & environment['M'] & review['M'] & location['L'] & budget['M'], level['L2'])
rule_119 = ctrl.Rule(taste['M'] & environment['M'] & review['M'] & location['L'] & budget['H'], level['L2'])
rule_120 = ctrl.Rule(taste['M'] & environment['M'] & review['M'] & location['M'] & budget['L'], level['L2'])
rule_121 = ctrl.Rule(taste['M'] & environment['M'] & review['M'] & location['M'] & budget['M'], level['L2'])
rule_122 = ctrl.Rule(taste['M'] & environment['M'] & review['M'] & location['M'] & budget['H'], level['L2'])
rule_123 = ctrl.Rule(taste['M'] & environment['M'] & review['M'] & location['H'] & budget['L'], level['L2'])
rule_124 = ctrl.Rule(taste['M'] & environment['M'] & review['M'] & location['H'] & budget['M'], level['L2'])
rule_125 = ctrl.Rule(taste['M'] & environment['M'] & review['M'] & location['H'] & budget['H'], level['L2'])
rule_126 = ctrl.Rule(taste['M'] & environment['M'] & review['H'] & location['L'] & budget['L'], level['L2'])
rule_127 = ctrl.Rule(taste['M'] & environment['M'] & review['H'] & location['L'] & budget['M'], level['L2'])
rule_128 = ctrl.Rule(taste['M'] & environment['M'] & review['H'] & location['L'] & budget['H'], level['L5'])
rule_129 = ctrl.Rule(taste['M'] & environment['M'] & review['H'] & location['M'] & budget['L'], level['L5'])
rule_130 = ctrl.Rule(taste['M'] & environment['M'] & review['H'] & location['M'] & budget['M'], level['L5'])
rule_131 = ctrl.Rule(taste['M'] & environment['M'] & review['H'] & location['M'] & budget['H'], level['L5'])
rule_132 = ctrl.Rule(taste['M'] & environment['M'] & review['H'] & location['H'] & budget['L'], level['L5'])
rule_133 = ctrl.Rule(taste['M'] & environment['M'] & review['H'] & location['H'] & budget['M'], level['L5'])
rule_134 = ctrl.Rule(taste['M'] & environment['M'] & review['H'] & location['H'] & budget['H'], level['L5'])
rule_135 = ctrl.Rule(taste['M'] & environment['H'] & review['L'] & location['L'] & budget['L'], level['L5'])
rule_136 = ctrl.Rule(taste['M'] & environment['H'] & review['L'] & location['L'] & budget['M'], level['L5'])
rule_137 = ctrl.Rule(taste['M'] & environment['H'] & review['L'] & location['L'] & budget['H'], level['L5'])
rule_138 = ctrl.Rule(taste['M'] & environment['H'] & review['L'] & location['M'] & budget['L'], level['L5'])
rule_139 = ctrl.Rule(taste['M'] & environment['H'] & review['L'] & location['M'] & budget['M'], level['L5'])
rule_140 = ctrl.Rule(taste['M'] & environment['H'] & review['L'] & location['M'] & budget['H'], level['L5'])
rule_141 = ctrl.Rule(taste['M'] & environment['H'] & review['L'] & location['H'] & budget['L'], level['L5'])
rule_142 = ctrl.Rule(taste['M'] & environment['H'] & review['L'] & location['H'] & budget['M'], level['L5'])
rule_143 = ctrl.Rule(taste['M'] & environment['H'] & review['L'] & location['H'] & budget['H'], level['L5'])
rule_144 = ctrl.Rule(taste['M'] & environment['H'] & review['M'] & location['L'] & budget['L'], level['L5'])
rule_145 = ctrl.Rule(taste['M'] & environment['H'] & review['M'] & location['L'] & budget['M'], level['L5'])
rule_146 = ctrl.Rule(taste['M'] & environment['H'] & review['M'] & location['L'] & budget['H'], level['L5'])
rule_147 = ctrl.Rule(taste['M'] & environment['H'] & review['M'] & location['M'] & budget['L'], level['L5'])
rule_148 = ctrl.Rule(taste['M'] & environment['H'] & review['M'] & location['M'] & budget['M'], level['L4'])
rule_149 = ctrl.Rule(taste['M'] & environment['H'] & review['M'] & location['M'] & budget['H'], level['L4'])
rule_150 = ctrl.Rule(taste['M'] & environment['H'] & review['M'] & location['H'] & budget['L'], level['L4'])
rule_151 = ctrl.Rule(taste['M'] & environment['H'] & review['M'] & location['H'] & budget['M'], level['L4'])
rule_152 = ctrl.Rule(taste['M'] & environment['H'] & review['M'] & location['H'] & budget['H'], level['L4'])
rule_153 = ctrl.Rule(taste['M'] & environment['H'] & review['H'] & location['L'] & budget['L'], level['L4'])
rule_154 = ctrl.Rule(taste['M'] & environment['H'] & review['H'] & location['L'] & budget['M'], level['L4'])
rule_155 = ctrl.Rule(taste['M'] & environment['H'] & review['H'] & location['L'] & budget['H'], level['L4'])
rule_156 = ctrl.Rule(taste['M'] & environment['H'] & review['H'] & location['M'] & budget['L'], level['L4'])
rule_157 = ctrl.Rule(taste['M'] & environment['H'] & review['H'] & location['M'] & budget['M'], level['L4'])
rule_158 = ctrl.Rule(taste['M'] & environment['H'] & review['H'] & location['M'] & budget['H'], level['L4'])
rule_159 = ctrl.Rule(taste['M'] & environment['H'] & review['H'] & location['H'] & budget['L'], level['L4'])
rule_160 = ctrl.Rule(taste['M'] & environment['H'] & review['H'] & location['H'] & budget['M'], level['L4'])
rule_161 = ctrl.Rule(taste['M'] & environment['H'] & review['H'] & location['H'] & budget['H'], level['L4'])
rule_162 = ctrl.Rule(taste['H'] & environment['L'] & review['L'] & location['L'] & budget['L'], level['L4'])
rule_163 = ctrl.Rule(taste['H'] & environment['L'] & review['L'] & location['L'] & budget['M'], level['L4'])
rule_164 = ctrl.Rule(taste['H'] & environment['L'] & review['L'] & location['L'] & budget['H'], level['L4'])
rule_165 = ctrl.Rule(taste['H'] & environment['L'] & review['L'] & location['M'] & budget['L'], level['L4'])
rule_166 = ctrl.Rule(taste['H'] & environment['L'] & review['L'] & location['M'] & budget['M'], level['L4'])
rule_167 = ctrl.Rule(taste['H'] & environment['L'] & review['L'] & location['M'] & budget['H'], level['L4'])
rule_168 = ctrl.Rule(taste['H'] & environment['L'] & review['L'] & location['H'] & budget['L'], level['L4'])
rule_169 = ctrl.Rule(taste['H'] & environment['L'] & review['L'] & location['H'] & budget['M'], level['L4'])
rule_170 = ctrl.Rule(taste['H'] & environment['L'] & review['L'] & location['H'] & budget['H'], level['L4'])
rule_171 = ctrl.Rule(taste['H'] & environment['L'] & review['M'] & location['L'] & budget['L'], level['L4'])
rule_172 = ctrl.Rule(taste['H'] & environment['L'] & review['M'] & location['L'] & budget['M'], level['L4'])
rule_173 = ctrl.Rule(taste['H'] & environment['L'] & review['M'] & location['L'] & budget['H'], level['L4'])
rule_174 = ctrl.Rule(taste['H'] & environment['L'] & review['M'] & location['M'] & budget['L'], level['L4'])
rule_175 = ctrl.Rule(taste['H'] & environment['L'] & review['M'] & location['M'] & budget['M'], level['L3'])
rule_176 = ctrl.Rule(taste['H'] & environment['L'] & review['M'] & location['M'] & budget['H'], level['L3'])
rule_177 = ctrl.Rule(taste['H'] & environment['L'] & review['M'] & location['H'] & budget['L'], level['L3'])
rule_178 = ctrl.Rule(taste['H'] & environment['L'] & review['M'] & location['H'] & budget['M'], level['L3'])
rule_179 = ctrl.Rule(taste['H'] & environment['L'] & review['M'] & location['H'] & budget['H'], level['L3'])
rule_180 = ctrl.Rule(taste['H'] & environment['L'] & review['H'] & location['L'] & budget['L'], level['L3'])
rule_181 = ctrl.Rule(taste['H'] & environment['L'] & review['H'] & location['L'] & budget['M'], level['L3'])
rule_182 = ctrl.Rule(taste['H'] & environment['L'] & review['H'] & location['L'] & budget['H'], level['L3'])
rule_183 = ctrl.Rule(taste['H'] & environment['L'] & review['H'] & location['M'] & budget['L'], level['L3'])
rule_184 = ctrl.Rule(taste['H'] & environment['L'] & review['H'] & location['M'] & budget['M'], level['L3'])
rule_185 = ctrl.Rule(taste['H'] & environment['L'] & review['H'] & location['M'] & budget['H'], level['L3'])
rule_186 = ctrl.Rule(taste['H'] & environment['L'] & review['H'] & location['H'] & budget['L'], level['L3'])
rule_187 = ctrl.Rule(taste['H'] & environment['L'] & review['H'] & location['H'] & budget['M'], level['L3'])
rule_188 = ctrl.Rule(taste['H'] & environment['L'] & review['H'] & location['H'] & budget['H'], level['L3'])
rule_189 = ctrl.Rule(taste['H'] & environment['M'] & review['L'] & location['L'] & budget['L'], level['L3'])
rule_190 = ctrl.Rule(taste['H'] & environment['M'] & review['L'] & location['L'] & budget['M'], level['L3'])
rule_191 = ctrl.Rule(taste['H'] & environment['M'] & review['L'] & location['L'] & budget['H'], level['L3'])
rule_192 = ctrl.Rule(taste['H'] & environment['M'] & review['L'] & location['M'] & budget['L'], level['L3'])
rule_193 = ctrl.Rule(taste['H'] & environment['M'] & review['L'] & location['M'] & budget['M'], level['L3'])
rule_194 = ctrl.Rule(taste['H'] & environment['M'] & review['L'] & location['M'] & budget['H'], level['L3'])
rule_195 = ctrl.Rule(taste['H'] & environment['M'] & review['L'] & location['H'] & budget['L'], level['L3'])
rule_196 = ctrl.Rule(taste['H'] & environment['M'] & review['L'] & location['H'] & budget['M'], level['L3'])
rule_197 = ctrl.Rule(taste['H'] & environment['M'] & review['L'] & location['H'] & budget['H'], level['L3'])
rule_198 = ctrl.Rule(taste['H'] & environment['M'] & review['M'] & location['L'] & budget['L'], level['L3'])
rule_199 = ctrl.Rule(taste['H'] & environment['M'] & review['M'] & location['L'] & budget['M'], level['L3'])
rule_200 = ctrl.Rule(taste['H'] & environment['M'] & review['M'] & location['L'] & budget['H'], level['L3'])
rule_201 = ctrl.Rule(taste['H'] & environment['M'] & review['M'] & location['M'] & budget['L'], level['L3'])
rule_202 = ctrl.Rule(taste['H'] & environment['M'] & review['M'] & location['M'] & budget['M'], level['L3'])
rule_203 = ctrl.Rule(taste['H'] & environment['M'] & review['M'] & location['M'] & budget['H'], level['L3'])
rule_204 = ctrl.Rule(taste['H'] & environment['M'] & review['M'] & location['H'] & budget['L'], level['L3'])
rule_205 = ctrl.Rule(taste['H'] & environment['M'] & review['M'] & location['H'] & budget['M'], level['L3'])
rule_206 = ctrl.Rule(taste['H'] & environment['M'] & review['M'] & location['H'] & budget['H'], level['L3'])
rule_207 = ctrl.Rule(taste['H'] & environment['M'] & review['H'] & location['L'] & budget['L'], level['L3'])
rule_208 = ctrl.Rule(taste['H'] & environment['M'] & review['H'] & location['L'] & budget['M'], level['L3'])
rule_209 = ctrl.Rule(taste['H'] & environment['M'] & review['H'] & location['L'] & budget['H'], level['L3'])
rule_210 = ctrl.Rule(taste['H'] & environment['M'] & review['H'] & location['M'] & budget['L'], level['L3'])
rule_211 = ctrl.Rule(taste['H'] & environment['M'] & review['H'] & location['M'] & budget['M'], level['L5'])
rule_212 = ctrl.Rule(taste['H'] & environment['M'] & review['H'] & location['M'] & budget['H'], level['L5'])
rule_213 = ctrl.Rule(taste['H'] & environment['M'] & review['H'] & location['H'] & budget['L'], level['L5'])
rule_214 = ctrl.Rule(taste['H'] & environment['M'] & review['H'] & location['H'] & budget['M'], level['L5'])
rule_215 = ctrl.Rule(taste['H'] & environment['M'] & review['H'] & location['H'] & budget['H'], level['L5'])
rule_216 = ctrl.Rule(taste['H'] & environment['H'] & review['L'] & location['L'] & budget['L'], level['L5'])
rule_217 = ctrl.Rule(taste['H'] & environment['H'] & review['L'] & location['L'] & budget['M'], level['L5'])
rule_218 = ctrl.Rule(taste['H'] & environment['H'] & review['L'] & location['L'] & budget['H'], level['L5'])
rule_219 = ctrl.Rule(taste['H'] & environment['H'] & review['L'] & location['M'] & budget['L'], level['L5'])
rule_220 = ctrl.Rule(taste['H'] & environment['H'] & review['L'] & location['M'] & budget['M'], level['L5'])
rule_221 = ctrl.Rule(taste['H'] & environment['H'] & review['L'] & location['M'] & budget['H'], level['L5'])
rule_222 = ctrl.Rule(taste['H'] & environment['H'] & review['L'] & location['H'] & budget['L'], level['L5'])
rule_223 = ctrl.Rule(taste['H'] & environment['H'] & review['L'] & location['H'] & budget['M'], level['L5'])
rule_224 = ctrl.Rule(taste['H'] & environment['H'] & review['L'] & location['H'] & budget['H'], level['L5'])
rule_225 = ctrl.Rule(taste['H'] & environment['H'] & review['M'] & location['L'] & budget['L'], level['L5'])
rule_226 = ctrl.Rule(taste['H'] & environment['H'] & review['M'] & location['L'] & budget['M'], level['L5'])
rule_227 = ctrl.Rule(taste['H'] & environment['H'] & review['M'] & location['L'] & budget['H'], level['L5'])
rule_228 = ctrl.Rule(taste['H'] & environment['H'] & review['M'] & location['M'] & budget['L'], level['L5'])
rule_229 = ctrl.Rule(taste['H'] & environment['H'] & review['M'] & location['M'] & budget['M'], level['L5'])
rule_230 = ctrl.Rule(taste['H'] & environment['H'] & review['M'] & location['M'] & budget['H'], level['L5'])
rule_231 = ctrl.Rule(taste['H'] & environment['H'] & review['M'] & location['H'] & budget['L'], level['L5'])
rule_232 = ctrl.Rule(taste['H'] & environment['H'] & review['M'] & location['H'] & budget['M'], level['L5'])
rule_233 = ctrl.Rule(taste['H'] & environment['H'] & review['M'] & location['H'] & budget['H'], level['L5'])
rule_234 = ctrl.Rule(taste['H'] & environment['H'] & review['H'] & location['L'] & budget['L'], level['L5'])
rule_235 = ctrl.Rule(taste['H'] & environment['H'] & review['H'] & location['L'] & budget['M'], level['L5'])
rule_236 = ctrl.Rule(taste['H'] & environment['H'] & review['H'] & location['L'] & budget['H'], level['L5'])
rule_237 = ctrl.Rule(taste['H'] & environment['H'] & review['H'] & location['M'] & budget['L'], level['L5'])
rule_238 = ctrl.Rule(taste['H'] & environment['H'] & review['H'] & location['M'] & budget['M'], level['L5'])
rule_239 = ctrl.Rule(taste['H'] & environment['H'] & review['H'] & location['M'] & budget['H'], level['L5'])
rule_240 = ctrl.Rule(taste['H'] & environment['H'] & review['H'] & location['H'] & budget['L'], level['L5'])
rule_241 = ctrl.Rule(taste['H'] & environment['H'] & review['H'] & location['H'] & budget['M'], level['L5'])
rule_242 = ctrl.Rule(taste['H'] & environment['H'] & review['H'] & location['H'] & budget['H'], level['L5'])


rule = [rule_1, rule_2, rule_3, rule_4, rule_5, rule_6, rule_7, rule_8, rule_9, rule_10, rule_11, rule_12, rule_13, rule_14, 
        rule_15, rule_16, rule_17, rule_18, rule_19, rule_20, rule_21, rule_22, rule_23, rule_24, rule_25, rule_26, rule_27,
        rule_28, rule_29, rule_30, rule_31, rule_32, rule_33, rule_34, rule_35, rule_36, rule_37, rule_38, rule_39, rule_40,
        rule_41, rule_42, rule_43, rule_44, rule_45, rule_46, rule_47, rule_48, rule_49, rule_50, rule_51, rule_52, rule_53,
        rule_54, rule_45, rule_56, rule_57, rule_58, rule_59, rule_60, rule_61, rule_62, rule_63, rule_64, rule_65, rule_66,
        rule_67, rule_68, rule_69, rule_70, rule_71, rule_72, rule_73, rule_74, rule_75, rule_76, rule_77, rule_78, rule_79, rule_80, 
        rule_81, rule_82, rule_83, rule_84, rule_85, rule_86, rule_87, rule_88, rule_89, rule_90, rule_91, rule_92, rule_93,
        rule_94, rule_95, rule_96, rule_97, rule_98, rule_99, rule_100, rule_101, rule_102, rule_103, rule_104, rule_105, rule_106,
        rule_107, rule_108, rule_109, rule_110, rule_111, rule_112, rule_113, rule_114, rule_115, rule_116, rule_117, rule_118, rule_119,
        rule_120, rule_121, rule_122, rule_123, rule_124, rule_125, rule_126, rule_127, rule_128, rule_129, rule_130, rule_131, rule_132,
        rule_133, rule_134, rule_135, rule_136, rule_137, rule_138, rule_139, rule_140, rule_141, rule_142, rule_143, rule_144,
        rule_145, rule_146, rule_147, rule_148, rule_149, rule_150, rule_151, rule_152, rule_153, rule_154, rule_155, rule_156,
        rule_157, rule_158, rule_159, rule_160, rule_161, rule_162, rule_163, rule_164, rule_165, rule_166, rule_167, rule_168,
        rule_169, rule_170, rule_171, rule_172, rule_173, rule_174, rule_175, rule_176, rule_177, rule_178, rule_179, rule_180,
        rule_181, rule_182, rule_183, rule_184, rule_185, rule_186, rule_187, rule_188, rule_189, rule_190, rule_191, rule_192, rule_193,
        rule_194, rule_195, rule_196, rule_197, rule_198, rule_199, rule_200, rule_201, rule_202, rule_203, rule_204, rule_205, rule_206,
        rule_207, rule_208, rule_209, rule_210, rule_211, rule_212, rule_213, rule_214, rule_215, rule_216, rule_217, rule_218, rule_219,
        rule_220, rule_221, rule_222, rule_223, rule_224, rule_225, rule_226, rule_227, rule_228, rule_229, rule_230, rule_231, rule_232,
        rule_233, rule_234, rule_235, rule_236, rule_237, rule_238, rule_239, rule_240, rule_241, rule_242]
leveling_ctrl = ctrl.ControlSystem(rule)
leveling = ctrl.ControlSystemSimulation(leveling_ctrl)
leveling.input['taste'] = 2
leveling.input['environment'] = 2.5
leveling.input['budget'] = 0.5
leveling.input['review'] = 1.5
leveling.input['location'] = 1.5

leveling.compute()
print(leveling.output['level'])
level.view(sim = leveling)
#food.view()
#service.view()
#tip.view()'''
